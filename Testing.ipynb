# %%
from lib import *

# %%
R_ell,Theta,z = basis_pol(1,1,2,200,200,10)

# %%
z.shape
# Out:
# (10, 40000)

# %%
import matplotlib.pyplot as plt

ax = plt.subplot(111, projection='polar')
ax.scatter(Theta,R_ell,c=z[3].imag)
