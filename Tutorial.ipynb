# %% [markdown]
# # Beam analysis tool for HIRAX
#
# This is an example notebook prepared for the *HIRAX collaboration meeting 2025 @ Capetown* by *Ajith Sampath* as a part of the basic internal version of the ***BeamLab21*** package.
#
# This tool was used in the research article [![arXiv](https://img.shields.io/badge/arXiv-2412.09527-b31b1b.svg)](https://arxiv.org/abs/2412.09527).
#
# Check out the paper for more background details on the method used in the package.
#
# Installation:
# * After unzipping the folder, `cd` into the **BeamLab21** directory.
# * And do `pip install .` And you will be ready to go!
#
# Usage:
# * Go through the two `.yaml` files in the **configs** folder and read each parameter.
# * Few important parameters are `N`, `skip_minimise` and `save_params`
# * To import fitting fucntionality, do `from beamlab21 import fit` and then run the config file by doing something like this:

# %%
from beamlab21 import fit

fit.run(config_path='configs/config_fit.yaml')
# Out:
# Project root: /Users/ajithsampath/SwissPostdoc/BeamPackage
# Config file path: configs/config_fit.yaml
# Fitting data from file: /Users/ajithsampath/SwissPostdoc/BeamPackage/data/Example_cube.npz
# Telescope: Hirax
# Frequency channel (MHz): 400
# Proceeding with uniform error array...
#
# Data loaded. Shape of observed data: (256, 256)
# Fitting a 2D Gaussian to calculate beam width...
#
# Starting Gaussian fit optimization...
#
# Initial Gaussian parameters: [1. 1. 1. 0. 0. 0.]
# Optimizing: 184iter [00:00, 236.87iter/s, Chi-square=1.0017]
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 184
#          Function evaluations: 319
# Gaussian fit completed. Optimized sigx: 3.9179299256003195 sigy: 5.2107520183139275
# Generating Zernike basis...
#
# Data normalized to maximum value.
#
# Skipping scaling parameter optimization for Zernike basis.....
#
# Good choice if you are running in a laptop :)
#
# Constructing the full basis set for the given N=15 and scaling parameters = [(np.float64(1.31), np.float64(1.74))]...
#  96%|█████████▋| [00:00] , 96.3%/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/site-packages/tqdm/std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# 100%|██████████| [00:00] , 100.0%
# No optimization done for scaling parameter... and the ZT model is constructed using Gaussian sigma!!
#
# Scaling parameters are saved in /Users/ajithsampath/SwissPostdoc/BeamPackage/outputs/scaleparameters_400.csv!
#
# Making the plot.....
#
# Plotted and saved...!!!
#
# Decomposing/Fitting the beam for a single given frequency is done!!

# %% [markdown]
# **Visualize the model here**
# * Try to visualise both main lobe model (Gaussian model saved) and full Zernike Model.

# %%
#Load model and visualise
#
#
#
#
#

# %% [markdown]
# **Coefficient Analysis**
# * You will find the saved files in `outputs` directory.
# * Now try to do a triangle plot of the coefficients like Figure 4 of the paper [![arXiv](https://img.shields.io/badge/arXiv-2412.09527-b31b1b.svg)](https://arxiv.org/abs/2412.09527).

# %%
#YOUR PLOTTING HERE

# %% [markdown]
# # Compute beam model from given coefficients
# * Although using the fitted coefficients from the previous task we can only obtain the same model, try changing paramters in `config_compute.yaml` like angular_resolution, pixels, etc.,

# %%
from beamlab21 import compute

compute.run(config_path='configs/config_compute.yaml')
# Out:
# Constructing the basis set for the given coefficients and scale parameters...
# 100%|█████████▉| [00:49] , 99.9%/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/site-packages/tqdm/std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# 100%|██████████| [00:49] , 100.0%
