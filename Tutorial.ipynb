# %%
# %env PYTHONPATH=$(pwd)/src
# Out:
# env: PYTHONPATH=$(pwd)/src

# %%
pwd
# Out:
# '/Users/ajithsampath/SwissPostdoc/BeamPackage'

# %%
# !python -m beamlab21.fit
# Out:
# Project root: /Users/ajithsampath/miniconda3/envs/py310/lib/python3.10
# Config file path: configs/config_fit.yaml
# Fitting data from file: /Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/data/sample_cart_symm.npz
# Telescope: Hirax
# Frequency channel (MHz): 400
# Traceback (most recent call last):
#   File "/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/site-packages/beamlab21/fit.py", line 122, in <module>
#     main()
#   File "/Users/ajithsampath/miniconda3/envs/py310/lib/python3.10/site-packages/beamlab21/fit.py", line 119, in main
#     run_fit(config_path)
# ...

# %%
from beamlab21.fit import run_fit
run_fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 from beamlab21.fit import run_fit
# ----> 2 run_fit()
#
# TypeError: run_fit() missing 1 required positional argument: 'config_path'

# %%
import os
os.system("export PYTHONPATH=$(pwd)/src")
os.system("python -m beamlab21.fit")
# Out:
# Loaded config: {'Telescope_name': 'Hirax', 'frequency': 400, 'aperture_diameter': 6.0, 'data_dir': 'data', 'datafile': 'sample_cart_symm.npz', 'normalize_data': True, 'coord_type': 'auto', 'gaussian_error_type': 'uniform', 'init_gparams': [1.0, 1.0, 1.0, 0, 0, 0], 'gminimize_method': 'Nelder-Mead', 'gtol': '1e-6', 'gverbose': True, 'zernike_error_type': 'proportional', 'N': 750, 'skip_minimise': True, 'fac': 3, 'ztminimize_method': 'Nelder-Mead', 'ztmaxiter': 10, 'zttol': '1e-6', 'zverbose': False, 'plot_results': True, 'plot_cmap': 'inferno', 'plot_format': '.png', 'plot_directory': 'outputs', 'save_outputs': True, 'output_dir': 'outputs', 'output_name': 'testbeam', 'output_format': '.npz', 'save_params': True, 'out_coef_dir': 'outputs', 'out_coef_name': 'coefficients.csv', 'out_sp_dir': 'outputs', 'out_sp_name': 'scaleparameters.csv'}
# Project root: /Users/ajithsampath/miniconda3/envs/py310/lib/python3.10
# Config file path: configs/config_fit.yaml
# ...
